# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshini5692/Weather-Model-Quadratic/blob/main/weather_model_quadratic_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Quadratic coefficients
a, b, c = -0.2, 1.5, 24

def quadratic_weather_model(time):
    """Predict temperature using quadratic equation."""
    return a * (time ** 2) + b * time + c

# ===== WATERFALL MODE =====
print("=== WATERFALL MODE ===")
for hour in range(0, 25, 6):  # every 6 hours
    temp = quadratic_weather_model(hour)
    print(f"Time: {hour} hrs -> Predicted Temp: {temp:.2f}°C")

# ===== ITERATIVE MODE =====
print("\n=== ITERATIVE MODE ===")
for iteration in range(1, 4):  # multiple cycles
    print(f"Iteration {iteration}:")
    for hour in range(0, 25, 12):  # every 12 hours
        temp = quadratic_weather_model(hour)
        print(f"Time: {hour} hrs -> Temp: {temp:.2f}°C")
    print("---")

# ===== AGILE MODE =====
print("\n=== AGILE MODE ===")
times_to_check = [0, 6, 12, 18, 24]
for sprint in range(1, 3):
    print(f"Sprint {sprint}:")
    for t in times_to_check:
        temp = quadratic_weather_model(t)
        print(f"Time: {t} hrs -> Temp: {temp:.2f}°C")
    print("---")

# ===== PLOTTING =====
time_values = np.linspace(0, 24, 100)
temp_values = quadratic_weather_model(time_values)

plt.plot(time_values, temp_values, label="Quadratic Fit")
plt.scatter([0, 6, 12, 18, 24], [quadratic_weather_model(t) for t in [0, 6, 12, 18, 24]], color="red", label="Sampled Points")
plt.xlabel("Time (hours)")
plt.ylabel("Temperature (°C)")
plt.title("Weather Modelling using Quadratic Equation")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# === WATERFALL MODE ===
# Time: 0 hrs -> Predicted Temp: 24.00°C
# Time: 6 hrs -> Predicted Temp: 25.80°C
# Time: 12 hrs -> Predicted Temp: 13.20°C
# Time: 18 hrs -> Predicted Temp: -13.80°C
# Time: 24 hrs -> Predicted Temp: -55.20°C
#
# === ITERATIVE MODE ===
# Iteration 1:
# Time: 0 hrs -> Temp: 24.00°C
# Time: 12 hrs -> Temp: 13.20°C
# Time: 24 hrs -> Temp: -55.20°C
# ---
# Iteration 2:
# Time: 0 hrs -> Temp: 24.00°C
# Time: 12 hrs -> Temp: 13.20°C
# Time: 24 hrs -> Temp: -55.20°C
# ---
# Iteration 3:
# Time: 0 hrs -> Temp: 24.00°C
# Time: 12 hrs -> Temp: 13.20°C
# Time: 24 hrs -> Temp: -55.20°C
# ---
#
# === AGILE MODE ===
# Sprint 1:
# Time: 0 hrs -> Temp: 24.00°C
# Time: 6 hrs -> Temp: 25.80°C
# Time: 12 hrs -> Temp: 13.20°C
# Time: 18 hrs -> Temp: -13.80°C
# Time: 24 hrs -> Temp: -55.20°C
# ---
# Sprint 2:
# Time: 0 hrs -> Temp: 24.00°C
# Time: 6 hrs -> Temp: 25.80°C
# Time: 12 hrs -> Temp: 13.20°C
# Time: 18 hrs -> Temp: -13.80°C
# Time: 24 hrs -> Temp: -55.20°C
# ---
